# %% [markdown]
# # Part 1: Using Gradient Descent to Solve Linear Regression
#
# In this part of the lab, you will be requested to solve the linear regression problem using gradient descent. This means you will not use the closed form solution of linear regression to find the model's parameters, but gradient descent.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt

# %% [markdown]
# For this exercise we will use some dummy data.

# %%
# We will use some dummy data
data = pd.read_csv('data/data.csv')
X = data.iloc[:, 0]
Y = data.iloc[:, 1]
plt.scatter(X, Y)
plt.show()

#Use a friendly format for X and y
X = X.to_numpy().reshape(-1,1)
y = Y.to_numpy().reshape(-1,1)

# %% [markdown]
# The data seems to follow a linear model of order one. Hence, we will try to fit the following linear regression model:
# \begin{equation}
# \hat{y} = \mathbf{w}^{T}\mathbf{x} + w_0
# \end{equation}
#
# Let us recall that for linear regression, we use the sum of squares loss function:
# \begin{equation}
# \mathcal{L} = \dfrac{1}{N}\sum_{i=1}^N(y_i - \hat{y})^2
# \end{equation}

# %% [markdown]
# ### Exercise 1: Implement the gradient descent function
# You will need to complete the gradient descent function for linear regression.

# %% [raw]
# def gradient_descent(alpha, epochs, epsilon, X, y):
#     '''
#     Performs gradient descent
#     Inputs:
#     alpha - learning rate
#     epochs - number of iterations
#     epsilon - threshold to stop iterations
#     X - Input matrix of size N x (D + 1)
#     y - Output vector of size N x 1
#
#     Outputs:
#     weights - Parameters vector of size (D + 1) x 1
#     '''
#
#     #Initialize weights
#     weights = np.zeros((X.shape[1]+1,1))
#
#     #Adds a one to the matrix so it copes with w_0
#     X = PolynomialFeatures(1).fit_transform(X)
#     N = len(X)
#     inv_N = float(1/N)
#     prev_gradient = 0
#     for e in range(epochs):
#
#         #1) Estimate y_hat
#         y_hat = np.dot(X,weights)
#
#         #2) Estimate the gradient
#         gradient = 2*alpha*inv_N*np.dot(np.transpose(X),y-y_hat) #your code here
#         gradient_norm = np.linalg.norm(gradient)
#
#         print ('Epoch ', e, ' weights: ', weights, 'gradient_norm: ', gradient_norm)
#
#         #3) Check the stopping criterion
#         if np.abs(gradient_norm - prev_gradient) <= epsilon:
#             break
#
#         #4) Update weights
#         weights = weights + gradient #your code here
#
#         #5) Update previous gradient
#         prev_gradient = gradient_norm
#
#     return weights

# %% [markdown]
# Now, test your implementation:

# %%
alpha = 0.0001  # The learning Rate
epochs = 1000  # The number of iterations to perform gradient descent
weights = gradient_descent(alpha, epochs, 0.00001, X, y)
# Out:
# Epoch  0  weights:  [[0.]
#  [0.]] gradient_norm:  0.7425776579805078
# Epoch  1  weights:  [[0.0146299 ]
#  [0.74243353]] gradient_norm:  0.37033612440799285
# Epoch  2  weights:  [[0.02196252]
#  [1.11269705]] gradient_norm:  0.18469294028442376
# Epoch  3  weights:  [[0.02565587]
#  [1.29735306]] gradient_norm:  0.09210953494141266
# Epoch  4  weights:  [[0.02753425]
#  [1.38944344]] gradient_norm:  0.04593663631259933
# Epoch  5  weights:  [[0.02850748]
#  [1.43536977]] gradient_norm:  0.02290946922247609
# Epoch  6  weights:  [[0.02902929]
#  [1.45827329]] gradient_norm:  0.011425516148926226
# Epoch  7  weights:  [[0.02932597]
#  [1.46969496]] gradient_norm:  0.005698447990588387
# Epoch  8  weights:  [[0.02951038]
#  [1.47539042]] gradient_norm:  0.002842611872105721
# Epoch  9  weights:  [[0.02963879]
#  [1.47823013]] gradient_norm:  0.0014190593492850747
# Epoch  10  weights:  [[0.02973928]
#  [1.47964563]] gradient_norm:  0.0007105101264507278
# Epoch  11  weights:  [[0.02982583]
#  [1.48035084]] gradient_norm:  0.00035990524904816023
# Epoch  12  weights:  [[0.02990545]
#  [1.48070183]] gradient_norm:  0.00019023509467589473
# Epoch  13  weights:  [[0.02998159]
#  [1.48087616]] gradient_norm:  0.00011390055314186523
# Epoch  14  weights:  [[0.03005601]
#  [1.48096239]] gradient_norm:  8.484698683361231e-05
# Epoch  15  weights:  [[0.03012957]
#  [1.48100468]] gradient_norm:  7.591291273414453e-05

# %%
y_hat = np.dot(PolynomialFeatures(1).fit_transform(X),weights)
plt.scatter(X, Y)
plt.plot([min(X), max(X)], [min(y_hat), max(y_hat)], color='red') # predicted
plt.show()

# %% [markdown]
# ### Question 1: Stopping criterion
# Explain what is being done at steps 3 and 5 of the code.

# %% [markdown]
# #Your answer
#
# In the step 3 we are comparing the difference between the previous gradient and the actual gradient. If it is samller than epsilon we assume it reached its minimum and we stop the descend.
#
# In the step 5 we are passing our actual gradient to be the previous gradient in order to compute what we have just described in the next iteration.

# %% [markdown]
# ### Exercise 2: Hyper-parameters
# Play a bit with the learning rate (alpha), the number of epochs and the stopping criterion. What can you say about the influence these have on your results? Make sure you document all your experiments.

# %%
# Your code and answer here
#Changing alpha(*2)
alpha = 0.0002  # The learning Rate
epochs = 1000  # The number of iterations to perform gradient descent
weights = gradient_descent(alpha, epochs, 0.00001, X, y)

y_hat = np.dot(PolynomialFeatures(1).fit_transform(X),weights)
plt.scatter(X, Y)
plt.plot([min(X), max(X)], [min(y_hat), max(y_hat)], color='red') # predicted
plt.show()
# Out:
# Epoch  0  weights:  [[0.]
#  [0.]] gradient_norm:  1.4851553159610156
# Epoch  1  weights:  [[0.02925979]
#  [1.48486706]] gradient_norm:  0.0038136141702968334
# Epoch  2  weights:  [[0.0293305]
#  [1.4810541]] gradient_norm:  0.00014576797711598306
# Epoch  3  weights:  [[0.0294761 ]
#  [1.48106102]] gradient_norm:  0.00014543748912106933

# %%
#Changing alpha (*10)
alpha = 0.001  # The learning Rate
epochs = 1000  # The number of iterations to perform gradient descent
weights = gradient_descent(alpha, epochs, 0.00001, X, y)

y_hat = np.dot(PolynomialFeatures(1).fit_transform(X),weights)
plt.scatter(X, Y)
plt.plot([min(X), max(X)], [min(y_hat), max(y_hat)], color='red') # predicted
plt.show()
# Out:
# Epoch  0  weights:  [[0.]
#  [0.]] gradient_norm:  7.425776579805078
# Epoch  1  weights:  [[0.14629895]
#  [7.42433529]] gradient_norm:  29.798377179839008
# Epoch  2  weights:  [[ -0.43712916]
#  [-22.36832982]] gradient_norm:  119.57581496760757
# Epoch  3  weights:  [[ 1.90771293]
#  [97.18449215]] gradient_norm:  479.8373898893591
# Epoch  4  weights:  [[  -7.49809508]
#  [-382.56070221]] gradient_norm:  1925.5057621973901
# Epoch  5  weights:  [[  30.24945519]
#  [1542.57502357]] gradient_norm:  7726.726842012013
# Epoch  6  weights:  [[ -121.22139462]
#  [-6182.66699676]] gradient_norm:  31006.039484888526
# Epoch  7  weights:  [[  486.60898388]
#  [24817.41408006]] gradient_norm:  124421.95824902905
# Epoch  8  weights:  [[ -1952.50721011]
#  [-99580.63416313]] gradient_norm:  499284.1379199058
# Epoch  9  weights:  [[  7835.25450483]
#  [399607.55690216]] gradient_norm:  2003542.2515974487
# Epoch  10  weights:  [[  -31441.36342961]
#  [-1603549.67637231]] gradient_norm:  8039873.989708289
# Epoch  11  weights:  [[ 126169.02186696]
#  [6434779.30027667]] gradient_norm:  32262645.681093033
# Epoch  12  weights:  [[  -506294.62043785]
#  [-25821666.5064906 ]] gradient_norm:  129464505.0004717
# Epoch  13  weights:  [[2.03167431e+06]
#  [1.03617959e+08]] gradient_norm:  519519019.633275
# Epoch  14  weights:  [[-8.15276298e+06]
#  [-4.15801225e+08]] gradient_norm:  2084741387.2994435
# Epoch  15  weights:  [[3.27156502e+07]
#  [1.66853954e+09]] gradient_norm:  8365712298.631771
# Epoch  16  weights:  [[-1.31282335e+08]
#  [-6.69556513e+09]] gradient_norm:  33570179346.867123
# Epoch  17  weights:  [[5.26813661e+08]
#  [2.68681631e+10]] gradient_norm:  134711415017.8389
# Epoch  18  weights:  [[-2.11401354e+09]
#  [-1.07817365e+11]] gradient_norm:  540573976343.7394
# Epoch  19  weights:  [[8.48317647e+09]
#  [4.32652730e+11]] gradient_norm:  2169231344362.2056
# Epoch  20  weights:  [[-3.40415431e+10]
#  [-1.73616176e+12]] gradient_norm:  8704756113474.641
# Epoch  21  weights:  [[1.36602917e+11]
#  [6.96692158e+12]] gradient_norm:  34930704459902.95
# Epoch  22  weights:  [[-5.48164253e+11]
#  [-2.79570703e+13]] gradient_norm:  140170970692255.19
# Epoch  23  weights:  [[2.19968983e+12]
#  [1.12186964e+14]] gradient_norm:  562482243876958.06
# Epoch  24  weights:  [[-8.82698084e+12]
#  [-4.50187188e+14]] gradient_norm:  2257145492496320.0
# Epoch  25  weights:  [[3.54211715e+13]
#  [1.80652455e+15]] gradient_norm:  9057540624181752.0
# Epoch  26  weights:  [[-1.42139131e+14]
#  [-7.24927550e+15]] gradient_norm:  3.634636864634304e+16
# Epoch  27  weights:  [[5.70380138e+14]
#  [2.90901085e+16]] gradient_norm:  1.458517900818371e+17
# Epoch  28  weights:  [[-2.28883840e+15]
#  [-1.16733653e+17]] gradient_norm:  5.852784050330872e+17
# Epoch  29  weights:  [[9.18471885e+15]
#  [4.68432279e+17]] gradient_norm:  2.3486226065917317e+18
# Epoch  30  weights:  [[-3.68567132e+16]
#  [-1.87973900e+18]] gradient_norm:  9.424622710762596e+18
# Epoch  31  weights:  [[1.47899716e+17]
#  [7.54307260e+18]] gradient_norm:  3.7819406570867e+19
# Epoch  32  weights:  [[-5.93496383e+17]
#  [-3.02690663e+19]] gradient_norm:  1.5176284051553347e+20
# Epoch  33  weights:  [[2.38159995e+18]
#  [1.21464610e+20]] gradient_norm:  6.08998444176678e+20
# Epoch  34  weights:  [[-9.55695519e+18]
#  [-4.87416804e+20]] gradient_norm:  2.443807085777717e+21
# Epoch  35  weights:  [[3.83504343e+19]
#  [1.95592066e+21]] gradient_norm:  9.80658182234169e+21
# Epoch  36  weights:  [[-1.53893764e+20]
#  [-7.84877664e+21]] gradient_norm:  3.935214346417103e+22
# Epoch  37  weights:  [[6.17549479e+20]
#  [3.14958046e+22]] gradient_norm:  1.5791345274830064e+23
# Epoch  38  weights:  [[-2.47812093e+21]
#  [-1.26387302e+23]] gradient_norm:  6.336798040389819e+23
# Epoch  39  weights:  [[9.94427745e+21]
#  [5.07170728e+23]] gradient_norm:  2.542849181360855e+24
# Epoch  40  weights:  [[-3.99046926e+22]
#  [-2.03518980e+24]] gradient_norm:  1.0204020891834825e+25
# Epoch  41  weights:  [[1.60130738e+23]
#  [8.16687020e+24]] gradient_norm:  4.094699879340805e+25
# Epoch  42  weights:  [[-6.42577393e+23]
#  [-3.27722599e+25]] gradient_norm:  1.6431333568995406e+26
# Epoch  43  weights:  [[2.57855369e+24]
#  [1.31509500e+26]] gradient_norm:  6.593614448223251e+26
# Epoch  44  weights:  [[-1.03472970e+25]
#  [-5.27725236e+26]] gradient_norm:  2.6459052340008275e+27
# Epoch  45  weights:  [[4.15219415e+25]
#  [2.11767154e+27]] gradient_norm:  1.0617567287695208e+28
# Epoch  46  weights:  [[-1.66620483e+26]
#  [-8.49785539e+27]] gradient_norm:  4.260649008138289e+28
# Epoch  47  weights:  [[6.68619634e+26]
#  [3.41004471e+28]] gradient_norm:  1.709725917309478e+29
# Epoch  48  weights:  [[-2.68305677e+27]
#  [-1.36839289e+29]] gradient_norm:  6.860839056998562e+29
# Epoch  49  weights:  [[1.07666501e+28]
#  [5.49112773e+29]] gradient_norm:  2.753137920498431e+30
# Epoch  50  weights:  [[-4.32047339e+28]
#  [-2.20349608e+30]] gradient_norm:  1.1047873804231718e+31
# Epoch  51  weights:  [[1.73373242e+29]
#  [8.84225467e+30]] gradient_norm:  4.433323688053098e+31
# Epoch  52  weights:  [[-6.95717308e+29]
#  [-3.54824627e+31]] gradient_norm:  1.7790173268927484e+32
# Epoch  53  weights:  [[2.79179513e+30]
#  [1.42385083e+32]] gradient_norm:  7.138893688077385e+32
# Epoch  54  weights:  [[-1.12029986e+31]
#  [-5.71367099e+32]] gradient_norm:  2.8647165105853736e+33
# Epoch  55  weights:  [[4.49557262e+31]
#  [2.29279890e+33]] gradient_norm:  1.1495619692062677e+34
# Epoch  56  weights:  [[-1.80399676e+32]
#  [-9.20061169e+33]] gradient_norm:  4.612996490795383e+34
# Epoch  57  weights:  [[7.23913192e+32]
#  [3.69204885e+34]] gradient_norm:  1.8511169640366093e+35
# Epoch  58  weights:  [[-2.90494041e+33]
#  [-1.48155635e+35]] gradient_norm:  7.428217258308134e+35
# Epoch  59  weights:  [[1.16570313e+34]
#  [5.94523343e+35]] gradient_norm:  2.980817134121167e+36
# Epoch  60  weights:  [[-4.67776824e+34]
#  [-2.38572097e+36]] gradient_norm:  1.196151173033145e+37
# Epoch  61  weights:  [[1.87710876e+35]
#  [9.57349213e+36]] gradient_norm:  4.799951034803766e+37
# Epoch  62  weights:  [[-7.53251792e+35]
#  [-3.84167942e+37]] gradient_norm:  1.9261386399923985e+38
# Epoch  63  weights:  [[3.02267122e+36]
#  [1.54160055e+38]] gradient_norm:  7.72926647286818e+38
# Epoch  64  weights:  [[-1.21294650e+37]
#  [-6.18618059e+38]] gradient_norm:  3.101623059118937e+39
# Epoch  65  weights:  [[4.86734784e+37]
#  [2.48240896e+39]] gradient_norm:  1.2446285342376728e+40
# Epoch  66  weights:  [[-1.95318383e+38]
#  [-9.96148459e+39]] gradient_norm:  4.994482432944844e+40
# Epoch  67  weights:  [[7.83779421e+38]
#  [3.99737419e+40]] gradient_norm:  2.004200778529733e+41
# Epoch  68  weights:  [[-3.14517339e+39]
#  [-1.60407821e+41]] gradient_norm:  8.042516546185534e+41
# Epoch  69  weights:  [[1.26210454e+40]
#  [6.43689281e+41]] gradient_norm:  3.2273249810389954e+42
# Epoch  70  weights:  [[-5.06461068e+40]
#  [-2.58301551e+42]] gradient_norm:  1.295070575661837e+43
# Epoch  71  weights:  [[2.03234205e+41]
#  [1.03652015e+43]] gradient_norm:  5.196897758356912e+43
# Epoch  72  weights:  [[-8.15544268e+41]
#  [-4.15937892e+43]] gradient_norm:  2.08542660287166e+44
# Epoch  73  weights:  [[3.27264031e+42]
#  [1.66908796e+44]] gradient_norm:  8.36846195207782e+44
# Epoch  74  weights:  [[-1.31325485e+43]
#  [-6.69776584e+44]] gradient_norm:  3.358121323806854e+45
# Epoch  75  weights:  [[5.26986815e+43]
#  [2.68769941e+45]] gradient_norm:  1.3475569214491465e+46
# Epoch  76  weights:  [[-2.11470838e+44]
#  [-1.07852802e+46]] gradient_norm:  5.407516529173339e+46
# Epoch  77  weights:  [[8.48596473e+44]
#  [4.32794935e+46]] gradient_norm:  2.1699443302058956e+47
# Epoch  78  weights:  [[-3.40527319e+45]
#  [-1.73673240e+47]] gradient_norm:  8.707617204292734e+47
# Epoch  79  weights:  [[1.36647816e+46]
#  [6.96921147e+47]] gradient_norm:  3.4942185530308227e+48
# Epoch  80  weights:  [[-5.48344425e+46]
#  [-2.79662593e+48]] gradient_norm:  1.4021704227335194e+49
# Epoch  81  weights:  [[2.20041283e+47]
#  [1.12223838e+49]] gradient_norm:  5.626671212890659e+49
# Epoch  82  weights:  [[-8.82988211e+47]
#  [-4.50335157e+49]] gradient_norm:  2.257887374079154e+50
# Epoch  83  weights:  [[3.54328138e+48]
#  [1.80711832e+50]] gradient_norm:  9.060517668682066e+50
# Epoch  84  weights:  [[-1.4218585e+49]
#  [-7.2516582e+50]] gradient_norm:  3.6358315019136115e+51
# Epoch  85  weights:  [[5.70567611e+49]
#  [2.90996699e+51]] gradient_norm:  1.4589972884220706e+52
# Epoch  86  weights:  [[-2.28959069e+50]
#  [-1.16772022e+52]] gradient_norm:  5.85470775117766e+52
# Epoch  87  weights:  [[9.18773770e+50]
#  [4.68586244e+52]] gradient_norm:  2.349394554994105e+53
# Epoch  88  weights:  [[-3.68688273e+51]
#  [-1.88035683e+53]] gradient_norm:  9.42772040829141e+53
# Epoch  89  weights:  [[1.47948328e+52]
#  [7.54555186e+53]] gradient_norm:  3.78318371037245e+54
# Epoch  90  weights:  [[-5.93691454e+52]
#  [-3.02790151e+54]] gradient_norm:  1.5181272212782258e+55
# Epoch  91  weights:  [[2.38238274e+53]
#  [1.21504533e+55]] gradient_norm:  6.09198610595374e+55
# Epoch  92  weights:  [[-9.56009638e+53]
#  [-4.87577008e+55]] gradient_norm:  2.4446103195413204e+56
# Epoch  93  weights:  [[3.83630394e+54]
#  [1.95656353e+56]] gradient_norm:  9.809805062699358e+56
# Epoch  94  weights:  [[-1.53944346e+55]
#  [-7.85135639e+56]] gradient_norm:  3.9365077779029386e+57
# Epoch  95  weights:  [[6.17752456e+55]
#  [3.15061566e+57]] gradient_norm:  1.579653559519998e+58
# Epoch  96  weights:  [[-2.47893544e+56]
#  [-1.26428843e+58]] gradient_norm:  6.338880827598676e+58
# Epoch  97  weights:  [[9.94754594e+56]
#  [5.07337426e+58]] gradient_norm:  2.5436849684121747e+59
# Epoch  98  weights:  [[-3.99178085e+57]
#  [-2.03585873e+59]] gradient_norm:  1.0207374762994511e+60
# Epoch  99  weights:  [[1.6018337e+58]
#  [8.1695545e+59]] gradient_norm:  4.096045730743743e+60
# Epoch  100  weights:  [[-6.42788596e+58]
#  [-3.27830315e+60]] gradient_norm:  1.643673424156913e+61
# Epoch  101  weights:  [[2.57940121e+59]
#  [1.31552725e+61]] gradient_norm:  6.595781646190643e+61
# Epoch  102  weights:  [[-1.0350698e+60]
#  [-5.2789869e+61]] gradient_norm:  2.646774893652609e+62
# Epoch  103  weights:  [[4.15355890e+60]
#  [2.11836758e+62]] gradient_norm:  1.0621057083834361e+63
# Epoch  104  weights:  [[-1.66675248e+61]
#  [-8.50064847e+62]] gradient_norm:  4.2620494039216206e+63
# Epoch  105  weights:  [[6.68839396e+61]
#  [3.41116552e+63]] gradient_norm:  1.7102878722981852e+64
# Epoch  106  weights:  [[-2.68393864e+62]
#  [-1.36884266e+64]] gradient_norm:  6.863094086705818e+64
# Epoch  107  weights:  [[1.07701889e+63]
#  [5.49293256e+64]] gradient_norm:  2.7540428255322517e+65
# Epoch  108  weights:  [[-4.32189345e+63]
#  [-2.20422033e+65]] gradient_norm:  1.105150503408913e+66
# Epoch  109  weights:  [[1.73430227e+64]
#  [8.84516095e+65]] gradient_norm:  4.434780838779921e+66
# Epoch  110  weights:  [[-6.95945978e+64]
#  [-3.54941252e+66]] gradient_norm:  1.7796020566741316e+67
# Epoch  111  weights:  [[2.79271274e+65]
#  [1.42431882e+67]] gradient_norm:  7.14124010915066e+67
# Epoch  112  weights:  [[-1.12066808e+66]
#  [-5.71554896e+67]] gradient_norm:  2.865658089418605e+68
# Epoch  113  weights:  [[4.49705023e+66]
#  [2.29355250e+68]] gradient_norm:  1.1499398087634088e+69
# Epoch  114  weights:  [[-1.80458970e+67]
#  [-9.20363576e+68]] gradient_norm:  4.614512696618004e+69
# Epoch  115  weights:  [[7.24151129e+67]
#  [3.69326236e+69]] gradient_norm:  1.851725391622631e+70
# Epoch  116  weights:  [[-2.90589521e+68]
#  [-1.48204331e+70]] gradient_norm:  7.430658774637314e+70
# Epoch  117  weights:  [[1.16608628e+69]
#  [5.94718752e+70]] gradient_norm:  2.981796873061776e+71
# Epoch  118  weights:  [[-4.67930573e+69]
#  [-2.38650511e+71]] gradient_norm:  1.1965443255917706e+72
# Epoch  119  weights:  [[1.87772573e+70]
#  [9.57663876e+71]] gradient_norm:  4.80152868909459e+72
# Epoch  120  weights:  [[-7.53499372e+70]
#  [-3.84294211e+72]] gradient_norm:  1.9267717258026644e+73
# Epoch  121  weights:  [[3.02366471e+71]
#  [1.54210725e+73]] gradient_norm:  7.731806938453644e+73
# Epoch  122  weights:  [[-1.21334518e+72]
#  [-6.18821388e+73]] gradient_norm:  3.102642504711663e+74
# Epoch  123  weights:  [[4.86894764e+72]
#  [2.48322489e+74]] gradient_norm:  1.2450376203998617e+75
# Epoch  124  weights:  [[-1.95382580e+73]
#  [-9.96475874e+74]] gradient_norm:  4.9961240260743665e+75
# Epoch  125  weights:  [[7.84037035e+73]
#  [3.99868805e+75]] gradient_norm:  2.0048595219075278e+76
# Epoch  126  weights:  [[-3.14620715e+74]
#  [-1.60460545e+76]] gradient_norm:  8.045159971221766e+76
# Epoch  127  weights:  [[1.26251937e+75]
#  [6.43900850e+76]] gradient_norm:  3.2283857425066206e+77
# Epoch  128  weights:  [[-5.06627532e+75]
#  [-2.58386450e+77]] gradient_norm:  1.2954962411812969e+78
# Epoch  129  weights:  [[2.03301004e+76]
#  [1.03686084e+78]] gradient_norm:  5.198605881624838e+78
# Epoch  130  weights:  [[-8.15812322e+76]
#  [-4.16074603e+78]] gradient_norm:  2.0861120436614438e+79
# Epoch  131  weights:  [[3.27371597e+77]
#  [1.66963655e+79]] gradient_norm:  8.371212509283621e+79
# Epoch  132  weights:  [[-1.31368649e+78]
#  [-6.69996727e+79]] gradient_norm:  3.359225075590402e+80
# Epoch  133  weights:  [[5.27160025e+78]
#  [2.68858281e+80]] gradient_norm:  1.3479998382505552e+81
# Epoch  134  weights:  [[-2.11540344e+79]
#  [-1.07888251e+81]] gradient_norm:  5.40929387889901e+81
# Epoch  135  weights:  [[8.48875391e+79]
#  [4.32937187e+81]] gradient_norm:  2.1706575503947202e+82
# Epoch  136  weights:  [[-3.40639244e+80]
#  [-1.73730323e+82]] gradient_norm:  8.710479235497964e+82
# Epoch  137  weights:  [[1.36692730e+81]
#  [6.97150212e+82]] gradient_norm:  3.4953670374327024e+83
# Epoch  138  weights:  [[-5.48524655e+81]
#  [-2.79754512e+83]] gradient_norm:  1.4026312899731754e+84
# Epoch  139  weights:  [[2.20113606e+82]
#  [1.12260724e+84]] gradient_norm:  5.628520594669289e+84
# Epoch  140  weights:  [[-8.83278433e+82]
#  [-4.50483173e+84]] gradient_norm:  2.2586294995046195e+85
# Epoch  141  weights:  [[3.54444599e+83]
#  [1.80771229e+85]] gradient_norm:  9.06349569168136e+85
# Epoch  142  weights:  [[-1.42232584e+84]
#  [-7.25404168e+85]] gradient_norm:  3.637026531847903e+86
# Epoch  143  weights:  [[5.70755146e+84]
#  [2.91092344e+86]] gradient_norm:  1.459476833591531e+87
# Epoch  144  weights:  [[-2.29034324e+85]
#  [-1.16810402e+87]] gradient_norm:  5.856632084309022e+87
# Epoch  145  weights:  [[9.19075754e+85]
#  [4.68740260e+87]] gradient_norm:  2.350166757121515e+88
# Epoch  146  weights:  [[-3.68809454e+86]
#  [-1.88097487e+88]] gradient_norm:  9.43081912397559e+88
# Epoch  147  weights:  [[1.47996956e+87]
#  [7.54803195e+88]] gradient_norm:  3.7844271722266196e+89
# Epoch  148  weights:  [[-5.93886590e+87]
#  [-3.02889673e+89]] gradient_norm:  1.5186262013526702e+90
# Epoch  149  weights:  [[2.38316579e+88]
#  [1.21544470e+90]] gradient_norm:  6.09398842805037e+90
# Epoch  150  weights:  [[-9.56323861e+88]
#  [-4.87737266e+90]] gradient_norm:  2.4454138173128743e+91
# Epoch  151  weights:  [[3.83756486e+89]
#  [1.95720662e+91]] gradient_norm:  9.813029362475997e+91
# Epoch  152  weights:  [[-1.53994945e+90]
#  [-7.85393698e+91]] gradient_norm:  3.9378016345155743e+92
# Epoch  153  weights:  [[6.17955499e+90]
#  [3.15165121e+92]] gradient_norm:  1.580172762153136e+93
# Epoch  154  weights:  [[-2.47975022e+91]
#  [-1.26470398e+93]] gradient_norm:  6.340964299380822e+93
# Epoch  155  weights:  [[9.95081552e+91]
#  [5.07504178e+93]] gradient_norm:  2.544521030171102e+94
# Epoch  156  weights:  [[-3.99309287e+92]
#  [-2.03652787e+94]] gradient_norm:  1.021072973650906e+95
# Epoch  157  weights:  [[1.60236019e+93]
#  [8.17223968e+94]] gradient_norm:  4.097392024502924e+95
# Epoch  158  weights:  [[-6.42999869e+93]
#  [-3.27938067e+95]] gradient_norm:  1.644213668924315e+96
# Epoch  159  weights:  [[2.58024902e+94]
#  [1.31595964e+96]] gradient_norm:  6.597949556475563e+96
# Epoch  160  weights:  [[-1.03541001e+95]
#  [-5.28072200e+96]] gradient_norm:  2.6476448391452914e+97
# Epoch  161  weights:  [[4.15492409e+95]
#  [2.11906384e+97]] gradient_norm:  1.0624548027004397e+98
# Epoch  162  weights:  [[-1.66730031e+96]
#  [-8.50344248e+97]] gradient_norm:  4.263450259988915e+98
# Epoch  163  weights:  [[6.69059231e+96]
#  [3.41228671e+98]] gradient_norm:  1.710850011991011e+99
# Epoch  164  weights:  [[-2.68482080e+97]
#  [-1.36929257e+99]] gradient_norm:  6.865349857599257e+99
# Epoch  165  weights:  [[1.07737288e+98]
#  [5.49473798e+99]] gradient_norm:  2.754948027991468e+100
# Epoch  166  weights:  [[-4.32331398e+098]
#  [-2.20494481e+100]] gradient_norm:  1.1055137457464019e+101
# Epoch  167  weights:  [[1.73487230e+099]
#  [8.84806819e+100]] gradient_norm:  4.4362384684449817e+101
# Epoch  168  weights:  [[-6.96174722e+099]
#  [-3.55057914e+101]] gradient_norm:  1.780186978645275e+102
# Epoch  169  weights:  [[2.79363065e+100]
#  [1.42478697e+102]] gradient_norm:  7.143587301448729e+102
# Epoch  170  weights:  [[-1.12103642e+101]
#  [-5.71742756e+102]] gradient_norm:  2.86659997773122e+103
# Epoch  171  weights:  [[4.49852833e+101]
#  [2.29430635e+103]] gradient_norm:  1.1503177725093573e+104
# Epoch  172  weights:  [[-1.80518284e+102]
#  [-9.20666082e+103]] gradient_norm:  4.616029400789172e+104
# Epoch  173  weights:  [[7.24389144e+102]
#  [3.69447626e+104]] gradient_norm:  1.852334019187442e+105
# Epoch  174  weights:  [[-2.90685032e+103]
#  [-1.48253043e+105]] gradient_norm:  7.433101093447329e+105
# Epoch  175  weights:  [[1.16646955e+104]
#  [5.94914225e+105]] gradient_norm:  2.9827769340242802e+106
# Epoch  176  weights:  [[-4.68084373e+104]
#  [-2.38728951e+106]] gradient_norm:  1.1969376073723022e+107
# Epoch  177  weights:  [[1.87834291e+105]
#  [9.57978642e+106]] gradient_norm:  4.8031068619309255e+107
# Epoch  178  weights:  [[-7.53747033e+105]
#  [-3.84420521e+107]] gradient_norm:  1.927405019696417e+108
# Epoch  179  weights:  [[3.02465853e+106]
#  [1.54261411e+108]] gradient_norm:  7.734348239042719e+108
# Epoch  180  weights:  [[-1.21374398e+107]
#  [-6.19024783e+108]] gradient_norm:  3.103662285377123e+109
# Epoch  181  weights:  [[4.87054798e+107]
#  [2.48404108e+109]] gradient_norm:  1.2454468410210334e+110
# Epoch  182  weights:  [[-1.95446799e+108]
#  [-9.96803397e+109]] gradient_norm:  4.997766158764899e+110
# Epoch  183  weights:  [[7.84294733e+108]
#  [4.00000235e+110]] gradient_norm:  2.0055184818019724e+111
# Epoch  184  weights:  [[-3.14724125e+109]
#  [-1.60513285e+111]] gradient_norm:  8.047804265102457e+111
# Epoch  185  weights:  [[1.26293434e+110]
#  [6.44112488e+111]] gradient_norm:  3.229446852626735e+112
# Epoch  186  weights:  [[-5.06794051e+110]
#  [-2.58471377e+112]] gradient_norm:  1.295922046609064e+113
# Epoch  187  weights:  [[2.03367825e+111]
#  [1.03720163e+113]] gradient_norm:  5.2003145663209786e+113
# Epoch  188  weights:  [[-8.16080464e+111]
#  [-4.16211359e+113]] gradient_norm:  2.0867977097428137e+114
# Epoch  189  weights:  [[3.27479198e+112]
#  [1.67018533e+114]] gradient_norm:  8.373963970546217e+114
# Epoch  190  weights:  [[-1.31411827e+113]
#  [-6.70216942e+114]] gradient_norm:  3.360329190156552e+115
# Epoch  191  weights:  [[5.27333293e+113]
#  [2.68946650e+115]] gradient_norm:  1.3484429006304462e+116
# Epoch  192  weights:  [[-2.11609874e+114]
#  [-1.07923712e+116]] gradient_norm:  5.411071812806349e+116
# Epoch  193  weights:  [[8.49154400e+114]
#  [4.33079485e+116]] gradient_norm:  2.1713710050057032e+117
# Epoch  194  weights:  [[-3.40751205e+115]
#  [-1.73787425e+117]] gradient_norm:  8.713342207399409e+117
# Epoch  195  weights:  [[1.36737658e+116]
#  [6.97379352e+117]] gradient_norm:  3.4965158993199603e+118
# Epoch  196  weights:  [[-5.48704945e+116]
#  [-2.79846463e+118]] gradient_norm:  1.403092308691287e+119
# Epoch  197  weights:  [[2.20185954e+117]
#  [1.12297622e+119]] gradient_norm:  5.630370584305172e+119
# Epoch  198  weights:  [[-8.83568750e+117]
#  [-4.50631239e+119]] gradient_norm:  2.2593718688528536e+120
# Epoch  199  weights:  [[3.54561098e+118]
#  [1.80830645e+120]] gradient_norm:  9.066474693501187e+120
# Epoch  200  weights:  [[-1.42279333e+119]
#  [-7.25642595e+120]] gradient_norm:  3.6382219545662137e+121
# Epoch  201  weights:  [[5.70942743e+119]
#  [2.91188021e+121]] gradient_norm:  1.4599565363785313e+122
# Epoch  202  weights:  [[-2.29109603e+120]
#  [-1.16848796e+122]] gradient_norm:  5.858557049932743e+122
# Epoch  203  weights:  [[9.19377837e+120]
#  [4.68894326e+122]] gradient_norm:  2.3509392130573402e+123
# Epoch  204  weights:  [[-3.68930675e+121]
#  [-1.88159311e+123]] gradient_norm:  9.433918858149745e+123
# Epoch  205  weights:  [[1.48045600e+122]
#  [7.55051284e+123]] gradient_norm:  3.7856710427834754e+124
# Epoch  206  weights:  [[-5.94081789e+122]
#  [-3.02989227e+124]] gradient_norm:  1.5191253454325443e+125
# Epoch  207  weights:  [[2.38394909e+123]
#  [1.21584419e+125]] gradient_norm:  6.0959914082728716e+125
# Epoch  208  weights:  [[-9.56638187e+123]
#  [-4.87897576e+125]] gradient_norm:  2.446217579179136e+126
# Epoch  209  weights:  [[3.83882619e+124]
#  [1.95784992e+126]] gradient_norm:  9.816254722019739e+126
# Epoch  210  weights:  [[-1.54045560e+125]
#  [-7.85651843e+126]] gradient_norm:  3.939095916394706e+127
# Epoch  211  weights:  [[6.1815861e+125]
#  [3.1526871e+127]] gradient_norm:  1.5806921354384807e+128
# Epoch  212  weights:  [[-2.48056527e+126]
#  [-1.26511967e+128]] gradient_norm:  6.343048455961235e+128
# Epoch  213  weights:  [[9.95408616e+126]
#  [5.07670985e+128]] gradient_norm:  2.5453573667279186e+129
# Epoch  214  weights:  [[-3.99440533e+127]
#  [-2.03719724e+129]] gradient_norm:  1.0214085812740756e+130
# Epoch  215  weights:  [[1.60288686e+128]
#  [8.17492574e+129]] gradient_norm:  4.0987387607637204e+130
# Epoch  216  weights:  [[-6.43211211e+128]
#  [-3.28045854e+130]] gradient_norm:  1.6447540912600828e+131
# Epoch  217  weights:  [[2.58109710e+129]
#  [1.31639217e+131]] gradient_norm:  6.600118179312104e+131
# Epoch  218  weights:  [[-1.03575033e+130]
#  [-5.28245768e+131]] gradient_norm:  2.6485150705728057e+132
# Epoch  219  weights:  [[4.15628974e+130]
#  [2.11976034e+132]] gradient_norm:  1.0628040117582222e+133
# Epoch  220  weights:  [[-1.66784832e+131]
#  [-8.50623740e+132]] gradient_norm:  4.264851576491422e+133
# Epoch  221  weights:  [[6.69279139e+131]
#  [3.41340827e+133]] gradient_norm:  1.7114123364486492e+134
# Epoch  222  weights:  [[-2.68570325e+132]
#  [-1.36974263e+134]] gradient_norm:  6.867606369922439e+134
# Epoch  223  weights:  [[1.077727e+133]
#  [5.496544e+134]] gradient_norm:  2.7558535279738194e+135
# Epoch  224  weights:  [[-4.32473497e+133]
#  [-2.20566954e+135]] gradient_norm:  1.1058771074748592e+136
# Epoch  225  weights:  [[1.73544252e+134]
#  [8.85097638e+135]] gradient_norm:  4.4376965772056805e+136
# Epoch  226  weights:  [[-6.96403542e+134]
#  [-3.55174615e+136]] gradient_norm:  1.7807720928693427e+137
# Epoch  227  weights:  [[2.79454886e+135]
#  [1.42525527e+137]] gradient_norm:  7.145935265225055e+137
# Epoch  228  weights:  [[-1.12140489e+136]
#  [-5.71930677e+137]] gradient_norm:  2.8675421756249258e+138
# Epoch  229  weights:  [[4.50000691e+136]
#  [2.29506045e+138]] gradient_norm:  1.1506958604849277e+139
# Epoch  230  weights:  [[-1.80577617e+137]
#  [-9.20968688e+138]] gradient_norm:  4.617546603472661e+139
# Epoch  231  weights:  [[7.24627237e+137]
#  [3.69569057e+139]] gradient_norm:  1.8529428467967598e+140
# Epoch  232  weights:  [[-2.90780575e+138]
#  [-1.48301771e+140]] gradient_norm:  7.435544215001904e+140
# Epoch  233  weights:  [[1.16685295e+139]
#  [5.95109762e+140]] gradient_norm:  2.9837573171145123e+141
# Epoch  234  weights:  [[-4.68238224e+139]
#  [-2.38807417e+141]] gradient_norm:  1.1973310184172058e+142
# Epoch  235  weights:  [[1.87896028e+140]
#  [9.58293512e+141]] gradient_norm:  4.8046855534831817e+142
# Epoch  236  weights:  [[-7.53994776e+140]
#  [-3.84546873e+142]] gradient_norm:  1.9280385217420392e+143
# Epoch  237  weights:  [[3.02565268e+141]
#  [1.54312114e+143]] gradient_norm:  7.736890374909813e+143
# Epoch  238  weights:  [[-1.21414292e+142]
#  [-6.19228245e+143]] gradient_norm:  3.1046824012254346e+144
# Epoch  239  weights:  [[4.87214883e+142]
#  [2.48485753e+144]] gradient_norm:  1.2458561961453785e+145
# Epoch  240  weights:  [[-1.95511039e+143]
#  [-9.97131028e+144]] gradient_norm:  4.999408831193771e+145
# Epoch  241  weights:  [[7.84552516e+143]
#  [4.00131707e+145]] gradient_norm:  2.0061776582842253e+146
# Epoch  242  weights:  [[-3.14827569e+144]
#  [-1.60566043e+146]] gradient_norm:  8.05044942811316e+146
# Epoch  243  weights:  [[1.26334944e+145]
#  [6.44324196e+146]] gradient_norm:  3.2305083115139325e+147
# Epoch  244  weights:  [[-5.06960625e+145]
#  [-2.58556331e+147]] gradient_norm:  1.2963479919911255e+148
# Epoch  245  weights:  [[2.03434669e+146]
#  [1.03754254e+148]] gradient_norm:  5.202023812629883e+148
# Epoch  246  weights:  [[-8.16348694e+146]
#  [-4.16348160e+148]] gradient_norm:  2.0874836011898246e+149
# Epoch  247  weights:  [[3.27586834e+147]
#  [1.67073429e+149]] gradient_norm:  8.376716336162753e+149
# Epoch  248  weights:  [[-1.3145502e+148]
#  [-6.7043723e+149]] gradient_norm:  3.36143366762454e+150
# Epoch  249  weights:  [[5.27506618e+148]
#  [2.69035047e+150]] gradient_norm:  1.3488861086366656e+151
# Epoch  250  weights:  [[-2.11679426e+149]
#  [-1.07959185e+151]] gradient_norm:  5.412850331087359e+151
# Epoch  251  weights:  [[8.49433501e+149]
#  [4.33221830e+151]] gradient_norm:  2.172084694115896e+152
# Epoch  252  weights:  [[-3.40863204e+150]
#  [-1.73844546e+152]] gradient_norm:  8.716206120306269e+152
# Epoch  253  weights:  [[1.36782601e+151]
#  [6.97608568e+152]] gradient_norm:  3.497665138816672e+153
# Epoch  254  weights:  [[-5.48885294e+151]
#  [-2.79938443e+153]] gradient_norm:  inf
# Epoch  255  weights:  [[2.20258325e+152]
#  [1.12334532e+154]] gradient_norm:  inf
# Epoch  256  weights:  [[-8.83859162e+152]
#  [-4.50779353e+154]] gradient_norm:  inf
# Epoch  257  weights:  [[3.54677636e+153]
#  [1.80890081e+155]] gradient_norm:  inf
# Epoch  258  weights:  [[-1.42326097e+154]
#  [-7.25881100e+155]] gradient_norm:  inf
# Epoch  259  weights:  [[5.71130401e+154]
#  [2.91283729e+156]] gradient_norm:  inf
# Epoch  260  weights:  [[-2.29184907e+155]
#  [-1.16887202e+157]] gradient_norm:  inf
# Epoch  261  weights:  [[9.19680019e+155]
#  [4.69048443e+157]] gradient_norm:  inf
# Epoch  262  weights:  [[-3.69051936e+156]
#  [-1.88221155e+158]] gradient_norm:  inf
# Epoch  263  weights:  [[1.48094259e+157]
#  [7.55299456e+158]] gradient_norm:  inf
# Epoch  264  weights:  [[-5.94277053e+157]
#  [-3.03088814e+159]] gradient_norm:  inf
# Epoch  265  weights:  [[2.38473265e+158]
#  [1.21624382e+160]] gradient_norm:  inf
# Epoch  266  weights:  [[-9.56952616e+158]
#  [-4.88057939e+160]] gradient_norm:  inf
# Epoch  267  weights:  [[3.84008794e+159]
#  [1.95849343e+161]] gradient_norm:  inf
# Epoch  268  weights:  [[-1.54096192e+160]
#  [-7.85910072e+161]] gradient_norm:  inf
# Epoch  269  weights:  [[6.18361787e+160]
#  [3.15372333e+162]] gradient_norm:  inf
# Epoch  270  weights:  [[-2.48138059e+161]
#  [-1.26553549e+163]] gradient_norm:  inf
# Epoch  271  weights:  [[9.95735789e+161]
#  [5.07837847e+163]] gradient_norm:  inf
# Epoch  272  weights:  [[-3.99571821e+162]
#  [-2.03786683e+164]] gradient_norm:  inf
# Epoch  273  weights:  [[1.60341370e+163]
#  [8.17761269e+164]] gradient_norm:  inf
# Epoch  274  weights:  [[-6.43422623e+163]
#  [-3.28153676e+165]] gradient_norm:  inf
# Epoch  275  weights:  [[2.58194545e+164]
#  [1.31682484e+166]] gradient_norm:  inf
# Epoch  276  weights:  [[-1.03609076e+165]
#  [-5.28419392e+166]] gradient_norm:  inf
# Epoch  277  weights:  [[4.15765584e+165]
#  [2.12045707e+167]] gradient_norm:  inf
# Epoch  278  weights:  [[-1.66839651e+166]
#  [-8.50903324e+167]] gradient_norm:  inf
# Epoch  279  weights:  [[6.69499118e+166]
#  [3.41453019e+168]] gradient_norm:  inf
# Epoch  280  weights:  [[-2.68658599e+167]
#  [-1.37019284e+169]] gradient_norm:  inf
# Epoch  281  weights:  [[1.07808122e+168]
#  [5.49835061e+169]] gradient_norm:  inf
# Epoch  282  weights:  [[-4.32615643e+168]
#  [-2.20639450e+170]] gradient_norm:  inf
# Epoch  283  weights:  [[1.73601293e+169]
#  [8.85388554e+170]] gradient_norm:  inf
# Epoch  284  weights:  [[-6.96632437e+169]
#  [-3.55291354e+171]] gradient_norm:  inf
# Epoch  285  weights:  [[2.79546738e+170]
#  [1.42572372e+172]] gradient_norm:  inf
# Epoch  286  weights:  [[-1.12177347e+171]
#  [-5.72118660e+172]] gradient_norm:  inf
# Epoch  287  weights:  [[4.50148598e+171]
#  [2.29581479e+173]] gradient_norm:  inf
# Epoch  288  weights:  [[-1.80636969e+172]
#  [-9.21271393e+173]] gradient_norm:  inf
# Epoch  289  weights:  [[7.24865408e+172]
#  [3.69690527e+174]] gradient_norm:  inf
# Epoch  290  weights:  [[-2.90876149e+173]
#  [-1.48350515e+175]] gradient_norm:  inf
# Epoch  291  weights:  [[1.16723647e+174]
#  [5.95305364e+175]] gradient_norm:  inf
# Epoch  292  weights:  [[-4.68392125e+174]
#  [-2.38885909e+176]] gradient_norm:  inf
# Epoch  293  weights:  [[1.87957786e+175]
#  [9.58608485e+176]] gradient_norm:  inf
# Epoch  294  weights:  [[-7.54242600e+175]
#  [-3.84673266e+177]] gradient_norm:  inf
# Epoch  295  weights:  [[3.02664716e+176]
#  [1.54362833e+178]] gradient_norm:  inf
# Epoch  296  weights:  [[-1.21454198e+177]
#  [-6.19431773e+178]] gradient_norm:  inf
# Epoch  297  weights:  [[4.87375022e+177]
#  [2.48567426e+179]] gradient_norm:  inf
# Epoch  298  weights:  [[-1.95575300e+178]
#  [-9.97458766e+179]] gradient_norm:  inf
# Epoch  299  weights:  [[7.84810384e+178]
#  [4.00263223e+180]] gradient_norm:  inf
# Epoch  300  weights:  [[-3.14931047e+179]
#  [-1.60618818e+181]] gradient_norm:  inf
# Epoch  301  weights:  [[1.26376468e+180]
#  [6.44535973e+181]] gradient_norm:  inf
# Epoch  302  weights:  [[-5.07127253e+180]
#  [-2.58641314e+182]] gradient_norm:  inf
# Epoch  303  weights:  [[2.03501534e+181]
#  [1.03788356e+183]] gradient_norm:  inf
# Epoch  304  weights:  [[-8.16617013e+181]
#  [-4.16485006e+183]] gradient_norm:  inf
# Epoch  305  weights:  [[3.27694506e+182]
#  [1.67128343e+184]] gradient_norm:  inf
# Epoch  306  weights:  [[-1.31498227e+183]
#  [-6.70657590e+184]] gradient_norm:  inf
# Epoch  307  weights:  [[5.27679999e+183]
#  [2.69123474e+185]] gradient_norm:  inf
# Epoch  308  weights:  [[-2.11749001e+184]
#  [-1.07994669e+186]] gradient_norm:  inf
# Epoch  309  weights:  [[8.49712694e+184]
#  [4.33364222e+186]] gradient_norm:  inf
# Epoch  310  weights:  [[-3.40975239e+185]
#  [-1.73901685e+187]] gradient_norm:  inf
# Epoch  311  weights:  [[1.36827559e+186]
#  [6.97837859e+187]] gradient_norm:  inf
# Epoch  312  weights:  [[-5.49065702e+186]
#  [-2.80030453e+188]] gradient_norm:  inf
# Epoch  313  weights:  [[2.20330720e+187]
#  [1.12371454e+189]] gradient_norm:  inf
# Epoch  314  weights:  [[-8.84149670e+187]
#  [-4.50927516e+189]] gradient_norm:  inf
# Epoch  315  weights:  [[3.54794212e+188]
#  [1.80949536e+190]] gradient_norm:  inf
# Epoch  316  weights:  [[-1.42372877e+189]
#  [-7.26119684e+190]] gradient_norm:  inf
# Epoch  317  weights:  [[5.71318121e+189]
#  [2.91379468e+191]] gradient_norm:  inf
# Epoch  318  weights:  [[-2.29260236e+190]
#  [-1.16925620e+192]] gradient_norm:  inf
# Epoch  319  weights:  [[9.19982301e+190]
#  [4.69202610e+192]] gradient_norm:  inf
# Epoch  320  weights:  [[-3.69173236e+191]
#  [-1.88283020e+193]] gradient_norm:  inf
# Epoch  321  weights:  [[1.48142935e+192]
#  [7.55547708e+193]] gradient_norm:  inf
# Epoch  322  weights:  [[-5.94472380e+192]
#  [-3.03188434e+194]] gradient_norm:  inf
# Epoch  323  weights:  [[2.38551646e+193]
#  [1.21664357e+195]] gradient_norm:  inf
# Epoch  324  weights:  [[-9.57267148e+193]
#  [-4.88218354e+195]] gradient_norm:  inf
# Epoch  325  weights:  [[3.84135011e+194]
#  [1.95913715e+196]] gradient_norm:  inf
# Epoch  326  weights:  [[-1.54146841e+195]
#  [-7.86168386e+196]] gradient_norm:  inf
# Epoch  327  weights:  [[6.18565031e+195]
#  [3.15475990e+197]] gradient_norm:  inf
# Epoch  328  weights:  [[-2.48219617e+196]
#  [-1.26595144e+198]] gradient_norm:  inf
# Epoch  329  weights:  [[9.96063068e+196]
#  [5.08004764e+198]] gradient_norm:  inf
# Epoch  330  weights:  [[-3.99703153e+197]
#  [-2.03853664e+199]] gradient_norm:  inf
# Epoch  331  weights:  [[1.60394071e+198]
#  [8.18030052e+199]] gradient_norm:  inf
# Epoch  332  weights:  [[-6.43634104e+198]
#  [-3.28261534e+200]] gradient_norm:  inf
# Epoch  333  weights:  [[2.58279409e+199]
#  [1.31725766e+201]] gradient_norm:  inf
# Epoch  334  weights:  [[-1.03643130e+200]
#  [-5.28593074e+201]] gradient_norm:  inf
# Epoch  335  weights:  [[4.15902238e+200]
#  [2.12115402e+202]] gradient_norm:  inf
# Epoch  336  weights:  [[-1.66894488e+201]
#  [-8.51183000e+202]] gradient_norm:  inf
# Epoch  337  weights:  [[6.69719170e+201]
#  [3.41565248e+203]] gradient_norm:  inf
# Epoch  338  weights:  [[-2.68746902e+202]
#  [-1.37064320e+204]] gradient_norm:  inf
# Epoch  339  weights:  [[1.07843557e+203]
#  [5.50015782e+204]] gradient_norm:  inf
# Epoch  340  weights:  [[-4.32757836e+203]
#  [-2.20711970e+205]] gradient_norm:  inf
# Epoch  341  weights:  [[1.73658353e+204]
#  [8.85679564e+205]] gradient_norm:  inf
# Epoch  342  weights:  [[-6.96861407e+204]
#  [-3.55408132e+206]] gradient_norm:  inf
# Epoch  343  weights:  [[2.79638620e+205]
#  [1.42619233e+207]] gradient_norm:  inf
# Epoch  344  weights:  [[-1.12214218e+206]
#  [-5.72306705e+207]] gradient_norm:  inf
# Epoch  345  weights:  [[4.50296553e+206]
#  [2.29656938e+208]] gradient_norm:  inf
# Epoch  346  weights:  [[-1.80696341e+207]
#  [-9.21574198e+208]] gradient_norm:  inf
# Epoch  347  weights:  [[7.25103658e+207]
#  [3.69812038e+209]] gradient_norm:  inf
# Epoch  348  weights:  [[-2.90971754e+208]
#  [-1.48399275e+210]] gradient_norm:  inf
# Epoch  349  weights:  [[1.16762012e+209]
#  [5.95501030e+210]] gradient_norm:  inf
# Epoch  350  weights:  [[-4.68546077e+209]
#  [-2.38964426e+211]] gradient_norm:  inf
# Epoch  351  weights:  [[1.88019564e+210]
#  [9.58923562e+211]] gradient_norm:  inf
# Epoch  352  weights:  [[-7.54490505e+210]
#  [-3.84799701e+212]] gradient_norm:  inf
# Epoch  353  weights:  [[3.02764196e+211]
#  [1.54413570e+213]] gradient_norm:  inf
# Epoch  354  weights:  [[-1.21494118e+212]
#  [-6.19635369e+213]] gradient_norm:  inf
# Epoch  355  weights:  [[4.87535213e+212]
#  [2.48649125e+214]] gradient_norm:  inf
# Epoch  356  weights:  [[-1.95639582e+213]
#  [-9.97786613e+214]] gradient_norm:  inf
# Epoch  357  weights:  [[7.85068337e+213]
#  [4.00394782e+215]] gradient_norm:  inf
# Epoch  358  weights:  [[-3.15034559e+214]
#  [-1.60671610e+216]] gradient_norm:  inf
# Epoch  359  weights:  [[1.26418006e+215]
#  [6.44747820e+216]] gradient_norm:  inf
# Epoch  360  weights:  [[-5.07293937e+215]
#  [-2.58726325e+217]] gradient_norm:  inf
# Epoch  361  weights:  [[2.03568421e+216]
#  [1.03822470e+218]] gradient_norm:  inf
# Epoch  362  weights:  [[-8.16885420e+216]
#  [-4.16621897e+218]] gradient_norm:  inf
# Epoch  363  weights:  [[3.27802213e+217]
#  [1.67183275e+219]] gradient_norm:  inf
# Epoch  364  weights:  [[-1.31541448e+218]
#  [-6.70878023e+219]] gradient_norm:  inf
# Epoch  365  weights:  [[5.27853438e+218]
#  [2.69211930e+220]] gradient_norm:  inf
# Epoch  366  weights:  [[-2.11818599e+219]
#  [-1.08030165e+221]] gradient_norm:  inf
# Epoch  367  weights:  [[8.49991979e+219]
#  [4.33506661e+221]] gradient_norm:  inf
# Epoch  368  weights:  [[-3.41087312e+220]
#  [-1.73958843e+222]] gradient_norm:  inf
# Epoch  369  weights:  [[1.36872532e+221]
#  [6.98067225e+222]] gradient_norm:  inf
# Epoch  370  weights:  [[-5.49246170e+221]
#  [-2.80122494e+223]] gradient_norm:  inf
# Epoch  371  weights:  [[2.20403138e+222]
#  [1.12408388e+224]] gradient_norm:  inf
# Epoch  372  weights:  [[-8.84440274e+222]
#  [-4.51075727e+224]] gradient_norm:  inf
# Epoch  373  weights:  [[3.54910826e+223]
#  [1.81009011e+225]] gradient_norm:  inf
# Epoch  374  weights:  [[-1.42419673e+224]
#  [-7.26358346e+225]] gradient_norm:  inf
# Epoch  375  weights:  [[5.71505902e+224]
#  [2.91475239e+226]] gradient_norm:  inf
# Epoch  376  weights:  [[-2.29335590e+225]
#  [-1.16964052e+227]] gradient_norm:  inf
# Epoch  377  weights:  [[9.20284682e+225]
#  [4.69356828e+227]] gradient_norm:  inf
# Epoch  378  weights:  [[-3.69294577e+226]
#  [-1.88344905e+228]] gradient_norm:  inf
# Epoch  379  weights:  [[1.48191627e+227]
#  [7.55796043e+228]] gradient_norm:  inf
# Epoch  380  weights:  [[-5.94667772e+227]
#  [-3.03288086e+229]] gradient_norm:  inf
# Epoch  381  weights:  [[2.38630054e+228]
#  [1.21704346e+230]] gradient_norm:  inf
# Epoch  382  weights:  [[-9.57581784e+228]
#  [-4.88378823e+230]] gradient_norm:  inf
# Epoch  383  weights:  [[3.84261269e+229]
#  [1.95978108e+231]] gradient_norm:  inf
# Epoch  384  weights:  [[-1.54197506e+230]
#  [-7.86426785e+231]] gradient_norm:  inf
# Epoch  385  weights:  [[6.18768342e+230]
#  [3.15579681e+232]] gradient_norm:  inf
# Epoch  386  weights:  [[-2.48301202e+231]
#  [-1.26636754e+233]] gradient_norm:  inf
# Epoch  387  weights:  [[9.96390456e+231]
#  [5.08171736e+233]] gradient_norm:  inf
# Epoch  388  weights:  [[-3.99834528e+232]
#  [-2.03920667e+234]] gradient_norm:  inf
# Epoch  389  weights:  [[1.60446790e+233]
#  [8.18298923e+234]] gradient_norm:  inf
# Epoch  390  weights:  [[-6.43845654e+233]
#  [-3.28369428e+235]] gradient_norm:  inf
# Epoch  391  weights:  [[2.58364301e+234]
#  [1.31769061e+236]] gradient_norm:  inf
# Epoch  392  weights:  [[-1.03677196e+235]
#  [-5.28766812e+236]] gradient_norm:  inf
# Epoch  393  weights:  [[4.16038937e+235]
#  [2.12185121e+237]] gradient_norm:  inf
# Epoch  394  weights:  [[-1.66949343e+236]
#  [-8.51462768e+237]] gradient_norm:  inf
# Epoch  395  weights:  [[6.69939294e+236]
#  [3.41677514e+238]] gradient_norm:  inf
# Epoch  396  weights:  [[-2.68835234e+237]
#  [-1.37109370e+239]] gradient_norm:  inf
# Epoch  397  weights:  [[1.07879003e+238]
#  [5.50196562e+239]] gradient_norm:  inf
# Epoch  398  weights:  [[-4.32900075e+238]
#  [-2.20784514e+240]] gradient_norm:  inf
# Epoch  399  weights:  [[1.73715431e+239]
#  [8.85970671e+240]] gradient_norm:  inf
# Epoch  400  weights:  [[-6.97090452e+239]
#  [-3.55524948e+241]] gradient_norm:  inf
# Epoch  401  weights:  [[2.79730532e+240]
#  [1.42666110e+242]] gradient_norm:  inf
# Epoch  402  weights:  [[-1.12251100e+241]
#  [-5.72494811e+242]] gradient_norm:  inf
# Epoch  403  weights:  [[4.50444558e+241]
#  [2.29732422e+243]] gradient_norm:  inf
# Epoch  404  weights:  [[-1.80755733e+242]
#  [-9.21877102e+243]] gradient_norm:  inf
# Epoch  405  weights:  [[7.25341986e+242]
#  [3.69933588e+244]] gradient_norm:  inf
# Epoch  406  weights:  [[-2.91067391e+243]
#  [-1.48448051e+245]] gradient_norm:  inf
# Epoch  407  weights:  [[1.16800389e+244]
#  [5.95696760e+245]] gradient_norm:  inf
# Epoch  408  weights:  [[-4.68700079e+244]
#  [-2.39042969e+246]] gradient_norm:  inf
# Epoch  409  weights:  [[1.88081363e+245]
#  [9.59238742e+246]] gradient_norm:  inf
# Epoch  410  weights:  [[-7.54738492e+245]
#  [-3.84926178e+247]] gradient_norm:  inf
# Epoch  411  weights:  [[3.02863709e+246]
#  [1.54464323e+248]] gradient_norm:  inf
# Epoch  412  weights:  [[-1.21534051e+247]
#  [-6.19839032e+248]] gradient_norm:  inf
# Epoch  413  weights:  [[4.87695457e+247]
#  [2.48730852e+249]] gradient_norm:  inf
# Epoch  414  weights:  [[-1.95703885e+248]
#  [-9.98114566e+249]] gradient_norm:  inf
# Epoch  415  weights:  [[7.85326374e+248]
#  [4.00526384e+250]] gradient_norm:  inf
# Epoch  416  weights:  [[-3.15138105e+249]
#  [-1.60724420e+251]] gradient_norm:  inf
# Epoch  417  weights:  [[1.26459557e+250]
#  [6.44959737e+251]] gradient_norm:  inf
# Epoch  418  weights:  [[-5.07460675e+250]
#  [-2.58811363e+252]] gradient_norm:  inf
# Epoch  419  weights:  [[2.03635330e+251]
#  [1.03856594e+253]] gradient_norm:  inf
# Epoch  420  weights:  [[-8.17153915e+251]
#  [-4.16758833e+253]] gradient_norm:  inf
# Epoch  421  weights:  [[3.27909955e+252]
#  [1.67238225e+254]] gradient_norm:  inf
# Epoch  422  weights:  [[-1.31584683e+253]
#  [-6.71098528e+254]] gradient_norm:  inf
# Epoch  423  weights:  [[5.28026933e+253]
#  [2.69300415e+255]] gradient_norm:  inf
# Epoch  424  weights:  [[-2.11888220e+254]
#  [-1.08065672e+256]] gradient_norm:  inf
# Epoch  425  weights:  [[8.50271355e+254]
#  [4.33649146e+256]] gradient_norm:  inf
# Epoch  426  weights:  [[-3.41199421e+255]
#  [-1.74016020e+257]] gradient_norm:  inf
# Epoch  427  weights:  [[1.36917519e+256]
#  [6.98296667e+257]] gradient_norm:  inf
# Epoch  428  weights:  [[-5.49426697e+256]
#  [-2.80214565e+258]] gradient_norm:  inf
# Epoch  429  weights:  [[2.20475581e+257]
#  [1.12445335e+259]] gradient_norm:  inf
# Epoch  430  weights:  [[-8.84730973e+257]
#  [-4.51223987e+259]] gradient_norm:  inf
# Epoch  431  weights:  [[3.55027478e+258]
#  [1.81068505e+260]] gradient_norm:  inf
# Epoch  432  weights:  [[-1.42466483e+259]
#  [-7.26597086e+260]] gradient_norm:  inf
# Epoch  433  weights:  [[5.71693746e+259]
#  [2.91571042e+261]] gradient_norm:  inf
# Epoch  434  weights:  [[-2.29410968e+260]
#  [-1.17002496e+262]] gradient_norm:  inf
# Epoch  435  weights:  [[9.20587162e+260]
#  [4.69511097e+262]] gradient_norm:  inf
# Epoch  436  weights:  [[-3.69415957e+261]
#  [-1.88406811e+263]] gradient_norm:  inf
# Epoch  437  weights:  [[1.48240335e+262]
#  [7.56044459e+263]] gradient_norm:  inf
# Epoch  438  weights:  [[-5.94863229e+262]
#  [-3.03387771e+264]] gradient_norm:  inf
# Epoch  439  weights:  [[2.38708487e+263]
#  [1.21744348e+265]] gradient_norm:  inf
# Epoch  440  weights:  [[-9.57896523e+263]
#  [-4.88539344e+265]] gradient_norm:  inf
# Epoch  441  weights:  [[3.84387568e+264]
#  [1.96042522e+266]] gradient_norm:  inf
# Epoch  442  weights:  [[-1.54248188e+265]
#  [-7.86685268e+266]] gradient_norm:  inf
# Epoch  443  weights:  [[6.18971719e+265]
#  [3.15683406e+267]] gradient_norm:  inf
# Epoch  444  weights:  [[-2.48382814e+266]
#  [-1.26678377e+268]] gradient_norm:  inf
# Epoch  445  weights:  [[9.96717951e+266]
#  [5.08338762e+268]] gradient_norm:  inf
# Epoch  446  weights:  [[-3.99965946e+267]
#  [-2.03987692e+269]] gradient_norm:  inf
# Epoch  447  weights:  [[1.60499526e+268]
#  [8.18567882e+269]] gradient_norm:  inf
# Epoch  448  weights:  [[-6.44057274e+268]
#  [-3.28477357e+270]] gradient_norm:  inf
# Epoch  449  weights:  [[2.58449220e+269]
#  [1.31812371e+271]] gradient_norm:  inf
# Epoch  450  weights:  [[-1.03711272e+270]
#  [-5.28940608e+271]] gradient_norm:  inf
# Epoch  451  weights:  [[4.16175681e+270]
#  [2.12254862e+272]] gradient_norm:  inf
# Epoch  452  weights:  [[-1.67004216e+271]
#  [-8.51742628e+272]] gradient_norm:  inf
# Epoch  453  weights:  [[6.70159491e+271]
#  [3.41789817e+273]] gradient_norm:  inf
# Epoch  454  weights:  [[-2.68923595e+272]
#  [-1.37154435e+274]] gradient_norm:  inf
# Epoch  455  weights:  [[1.07914461e+273]
#  [5.50377401e+274]] gradient_norm:  inf
# Epoch  456  weights:  [[-4.33042361e+273]
#  [-2.20857082e+275]] gradient_norm:  inf
# Epoch  457  weights:  [[1.73772528e+274]
#  [8.86261873e+275]] gradient_norm:  inf
# Epoch  458  weights:  [[-6.97319573e+274]
#  [-3.55641803e+276]] gradient_norm:  inf
# Epoch  459  weights:  [[2.79822474e+275]
#  [1.42713001e+277]] gradient_norm:  inf
# Epoch  460  weights:  [[-1.12287995e+276]
#  [-5.72682980e+277]] gradient_norm:  inf
# Epoch  461  weights:  [[4.50592610e+276]
#  [2.29807931e+278]] gradient_norm:  inf
# Epoch  462  weights:  [[-1.80815144e+277]
#  [-9.22180106e+278]] gradient_norm:  inf
# Epoch  463  weights:  [[7.25580392e+277]
#  [3.70055178e+279]] gradient_norm:  inf
# Epoch  464  weights:  [[-2.91163060e+278]
#  [-1.48496843e+280]] gradient_norm:  inf
# Epoch  465  weights:  [[1.16838779e+279]
#  [5.95892554e+280]] gradient_norm:  inf
# Epoch  466  weights:  [[-4.68854132e+279]
#  [-2.39121538e+281]] gradient_norm:  inf
# Epoch  467  weights:  [[1.88143182e+280]
#  [9.59554026e+281]] gradient_norm:  inf
# Epoch  468  weights:  [[-7.54986561e+280]
#  [-3.85052696e+282]] gradient_norm:  inf
# Epoch  469  weights:  [[3.02963255e+281]
#  [1.54515092e+283]] gradient_norm:  inf
# Epoch  470  weights:  [[-1.21573997e+282]
#  [-6.20042761e+283]] gradient_norm:  inf
# Epoch  471  weights:  [[4.87855753e+282]
#  [2.48812605e+284]] gradient_norm:  inf
# Epoch  472  weights:  [[-1.95768209e+283]
#  [-9.98442628e+284]] gradient_norm:  inf
# Epoch  473  weights:  [[7.85584496e+283]
#  [4.00658030e+285]] gradient_norm:  inf
# Epoch  474  weights:  [[-3.15241685e+284]
#  [-1.60777247e+286]] gradient_norm:  inf
# Epoch  475  weights:  [[1.26501122e+285]
#  [6.45171723e+286]] gradient_norm:  inf
# Epoch  476  weights:  [[-5.07627468e+285]
#  [-2.58896429e+287]] gradient_norm:  inf
# Epoch  477  weights:  [[2.03702261e+286]
#  [1.03890730e+288]] gradient_norm:  inf
# Epoch  478  weights:  [[-8.17422498e+286]
#  [-4.16895814e+288]] gradient_norm:  inf
# Epoch  479  weights:  [[3.28017733e+287]
#  [1.67293193e+289]] gradient_norm:  inf
# Epoch  480  weights:  [[-1.31627933e+288]
#  [-6.71319106e+289]] gradient_norm:  inf
# Epoch  481  weights:  [[5.28200486e+288]
#  [2.69388929e+290]] gradient_norm:  inf
# Epoch  482  weights:  [[-2.11957863e+289]
#  [-1.08101191e+291]] gradient_norm:  inf
# Epoch  483  weights:  [[8.50550824e+289]
#  [4.33791679e+291]] gradient_norm:  inf
# Epoch  484  weights:  [[-3.41311567e+290]
#  [-1.74073216e+292]] gradient_norm:  inf
# Epoch  485  weights:  [[1.36962521e+291]
#  [6.98526184e+292]] gradient_norm:  inf
# Epoch  486  weights:  [[-5.49607283e+291]
#  [-2.80306667e+293]] gradient_norm:  inf
# Epoch  487  weights:  [[2.20548047e+292]
#  [1.12482294e+294]] gradient_norm:  inf
# Epoch  488  weights:  [[-8.85021767e+292]
#  [-4.51372296e+294]] gradient_norm:  inf
# Epoch  489  weights:  [[3.55144169e+293]
#  [1.81128019e+295]] gradient_norm:  inf
# Epoch  490  weights:  [[-1.42513309e+294]
#  [-7.26835905e+295]] gradient_norm:  inf
# Epoch  491  weights:  [[5.71881651e+294]
#  [2.91666876e+296]] gradient_norm:  inf
# Epoch  492  weights:  [[-2.29486371e+295]
#  [-1.17040952e+297]] gradient_norm:  inf
# Epoch  493  weights:  [[9.20889742e+295]
#  [4.69665417e+297]] gradient_norm:  inf
# Epoch  494  weights:  [[-3.69537377e+296]
#  [-1.88468737e+298]] gradient_norm:  inf
# Epoch  495  weights:  [[1.48289059e+297]
#  [7.56292957e+298]] gradient_norm:  inf
# Epoch  496  weights:  [[-5.95058749e+297]
#  [-3.03487489e+299]] gradient_norm:  inf
# Epoch  497  weights:  [[2.38786946e+298]
#  [1.21784363e+300]] gradient_norm:  inf
# Epoch  498  weights:  [[-9.58211366e+298]
#  [-4.88699917e+300]] gradient_norm:  inf
# Epoch  499  weights:  [[3.84513909e+299]
#  [1.96106958e+301]] gradient_norm:  inf
# Epoch  500  weights:  [[-1.54298886e+300]
#  [-7.86943837e+301]] gradient_norm:  inf
# Epoch  501  weights:  [[6.19175164e+300]
#  [3.15787166e+302]] gradient_norm:  inf
# Epoch  502  weights:  [[-2.48464453e+301]
#  [-1.26720014e+303]] gradient_norm:  inf
# Epoch  503  weights:  [[9.97045553e+301]
#  [            inf]] gradient_norm:  inf
# Epoch  504  weights:  [[-inf]
#  [ nan]] gradient_norm:  nan
# Epoch  505  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  506  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  507  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  508  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  509  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  510  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  511  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  512  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  513  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  514  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  515  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  516  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  517  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  518  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  519  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  520  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  521  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  522  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  523  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  524  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  525  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  526  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  527  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  528  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  529  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  530  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  531  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  532  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  533  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  534  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  535  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  536  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  537  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  538  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  539  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  540  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  541  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  542  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  543  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  544  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  545  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  546  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  547  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# ...
#  [nan]] gradient_norm:  nan
# Epoch  726  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  727  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  728  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  729  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  730  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  731  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  732  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  733  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  734  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  735  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  736  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  737  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  738  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  739  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  740  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  741  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  742  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  743  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  744  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  745  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  746  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  747  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  748  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  749  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  750  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  751  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  752  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  753  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  754  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  755  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  756  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  757  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  758  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  759  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  760  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  761  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  762  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  763  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  764  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  765  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  766  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  767  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  768  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  769  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  770  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  771  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  772  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  773  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  774  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  775  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  776  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  777  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  778  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  779  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  780  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  781  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  782  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  783  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  784  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  785  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  786  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  787  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  788  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  789  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  790  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  791  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  792  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  793  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  794  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  795  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  796  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  797  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  798  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  799  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  800  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  801  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  802  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  803  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  804  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  805  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  806  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  807  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  808  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  809  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  810  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  811  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  812  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  813  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  814  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  815  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  816  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  817  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  818  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  819  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  820  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  821  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  822  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  823  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  824  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  825  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  826  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  827  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  828  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  829  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  830  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  831  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  832  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  833  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  834  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  835  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  836  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  837  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  838  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  839  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  840  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  841  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  842  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  843  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  844  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  845  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  846  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  847  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  848  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  849  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  850  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  851  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  852  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  853  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  854  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  855  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  856  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  857  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  858  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  859  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  860  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  861  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  862  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  863  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  864  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  865  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  866  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  867  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  868  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  869  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  870  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  871  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  872  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  873  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  874  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  875  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  876  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  877  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  878  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  879  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  880  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  881  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  882  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  883  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  884  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  885  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  886  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  887  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  888  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  889  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  890  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  891  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  892  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  893  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  894  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  895  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  896  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  897  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  898  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  899  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  900  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  901  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  902  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  903  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  904  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  905  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  906  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  907  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  908  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  909  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  910  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  911  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  912  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  913  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  914  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  915  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  916  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  917  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  918  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  919  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  920  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  921  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  922  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  923  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  924  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  925  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  926  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  927  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  928  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  929  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  930  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  931  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  932  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  933  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  934  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  935  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  936  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  937  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  938  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  939  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  940  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  941  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  942  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  943  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  944  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  945  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  946  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  947  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  948  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  949  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  950  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  951  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  952  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  953  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  954  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  955  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  956  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  957  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  958  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  959  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  960  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  961  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  962  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  963  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  964  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  965  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  966  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  967  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  968  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  969  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  970  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  971  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  972  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  973  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  974  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  975  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  976  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  977  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  978  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  979  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  980  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  981  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  982  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  983  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  984  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  985  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  986  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  987  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  988  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  989  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  990  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  991  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  992  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  993  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  994  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  995  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  996  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  997  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  998  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# Epoch  999  weights:  [[nan]
#  [nan]] gradient_norm:  nan
# C:\Users\victo\AppData\Local\Temp\ipykernel_28936\290455994.py:35: RuntimeWarning: invalid value encountered in scalar subtract
#   if np.abs(gradient_norm - prev_gradient) <= epsilon:
# C:\Users\victo\AppData\Local\Temp\ipykernel_28936\290455994.py:39: RuntimeWarning: invalid value encountered in add
#   weights = weights + gradient #your code here

# %%
#Changing alpha (*2)
alpha = 0.00005  # The learning Rate
epochs = 1000  # The number of iterations to perform gradient descent
weights = gradient_descent(alpha, epochs, 0.00001, X, y)

y_hat = np.dot(PolynomialFeatures(1).fit_transform(X),weights)
plt.scatter(X, Y)
plt.plot([min(X), max(X)], [min(y_hat), max(y_hat)], color='red') # predicted
plt.show()
# Out:
# Epoch  0  weights:  [[0.]
#  [0.]] gradient_norm:  0.3712888289902539
# Epoch  1  weights:  [[0.00731495]
#  [0.37121676]] gradient_norm:  0.2782284452978447
# Epoch  2  weights:  [[0.01280558]
#  [0.64939103]] gradient_norm:  0.20849285503604895
# Epoch  3  weights:  [[0.01692914]
#  [0.8578431 ]] gradient_norm:  0.1562358973787201
# Epoch  4  weights:  [[0.02002828]
#  [1.01404826]] gradient_norm:  0.11707670198973388
# Epoch  5  weights:  [[0.02235975]
#  [1.13110174]] gradient_norm:  0.0877324264466289
# Epoch  6  weights:  [[0.02411598]
#  [1.21881659]] gradient_norm:  0.06574304490738941
# Epoch  7  weights:  [[0.02544113]
#  [1.28454628]] gradient_norm:  0.04926511616123633
# Epoch  8  weights:  [[0.02644326]
#  [1.3338012 ]] gradient_norm:  0.0369172419698933
# Epoch  9  weights:  [[0.02720332]
#  [1.37071062]] gradient_norm:  0.027664259970583364
# Epoch  10  weights:  [[0.02778199]
#  [1.39836882]] gradient_norm:  0.020730462656015105
# Epoch  11  weights:  [[0.02822473]
#  [1.41909456]] gradient_norm:  0.015534567296842296
# Epoch  12  weights:  [[0.02856562]
#  [1.43462539]] gradient_norm:  0.011640985124168281
# Epoch  13  weights:  [[0.02883017]
#  [1.44626336]] gradient_norm:  0.008723304509525054
# Epoch  14  weights:  [[0.02903753]
#  [1.4549842 ]] gradient_norm:  0.0065369268187909805
# Epoch  15  weights:  [[0.02920203]
#  [1.46151906]] gradient_norm:  0.0048985609148453355
# Epoch  16  weights:  [[0.02933441]
#  [1.46641583]] gradient_norm:  0.0036708572664904456
# Epoch  17  weights:  [[0.02944272]
#  [1.47008509]] gradient_norm:  0.0027508934909235136
# Epoch  18  weights:  [[0.02953299]
#  [1.4728345 ]] gradient_norm:  0.002061546034928319
# Epoch  19  weights:  [[0.02960975]
#  [1.47489462]] gradient_norm:  0.0015450246536659325
# Epoch  20  weights:  [[0.02967638]
#  [1.47643821]] gradient_norm:  0.0011580276586895736
# Epoch  21  weights:  [[0.02973543]
#  [1.47759473]] gradient_norm:  0.0008681117773950118
# Epoch  22  weights:  [[0.02978878]
#  [1.4784612 ]] gradient_norm:  0.000650972282055045
# Epoch  23  weights:  [[0.02983787]
#  [1.47911032]] gradient_norm:  0.0004884053365931956
# Epoch  24  weights:  [[0.02988377]
#  [1.47959656]] gradient_norm:  0.0003667816533105128
# Epoch  25  weights:  [[0.02992728]
#  [1.47996075]] gradient_norm:  0.0002759033057616855
# Epoch  26  weights:  [[0.02996899]
#  [1.48023349]] gradient_norm:  0.00020814741987738042
# Epoch  27  weights:  [[0.03000936]
#  [1.48043768]] gradient_norm:  0.00015782400335928395
# Epoch  28  weights:  [[0.03004872]
#  [1.48059052]] gradient_norm:  0.00012069217501674196
# Epoch  29  weights:  [[0.03008733]
#  [1.48070487]] gradient_norm:  9.359098741418624e-05
# Epoch  30  weights:  [[0.03012537]
#  [1.48079038]] gradient_norm:  7.41500651834519e-05
# Epoch  31  weights:  [[0.03016298]
#  [1.48085428]] gradient_norm:  6.055599898214082e-05
# Epoch  32  weights:  [[0.03020028]
#  [1.48090199]] gradient_norm:  5.13686116540175e-05

# %%
#Changing number of epochs (5)
alpha = 0.0001  # The learning Rate
epochs = 5  # The number of iterations to perform gradient descent
weights = gradient_descent(alpha, epochs, 0.00001, X, y)

y_hat = np.dot(PolynomialFeatures(1).fit_transform(X),weights)
plt.scatter(X, Y)
plt.plot([min(X), max(X)], [min(y_hat), max(y_hat)], color='red') # predicted
plt.show()
# Out:
# Epoch  0  weights:  [[0.]
#  [0.]] gradient_norm:  0.7425776579805078
# Epoch  1  weights:  [[0.0146299 ]
#  [0.74243353]] gradient_norm:  0.37033612440799285
# Epoch  2  weights:  [[0.02196252]
#  [1.11269705]] gradient_norm:  0.18469294028442376
# Epoch  3  weights:  [[0.02565587]
#  [1.29735306]] gradient_norm:  0.09210953494141266
# Epoch  4  weights:  [[0.02753425]
#  [1.38944344]] gradient_norm:  0.04593663631259933

# %%
#Changing epsilon (*1000)
alpha = 0.0001  # The learning Rate
epochs = 1000  # The number of iterations to perform gradient descent
weights = gradient_descent(alpha, epochs, 0.01, X, y)

y_hat = np.dot(PolynomialFeatures(1).fit_transform(X),weights)
plt.scatter(X, Y)
plt.plot([min(X), max(X)], [min(y_hat), max(y_hat)], color='red') # predicted
plt.show()
# Out:
# Epoch  0  weights:  [[0.]
#  [0.]] gradient_norm:  0.7425776579805078
# Epoch  1  weights:  [[0.0146299 ]
#  [0.74243353]] gradient_norm:  0.37033612440799285
# Epoch  2  weights:  [[0.02196252]
#  [1.11269705]] gradient_norm:  0.18469294028442376
# Epoch  3  weights:  [[0.02565587]
#  [1.29735306]] gradient_norm:  0.09210953494141266
# Epoch  4  weights:  [[0.02753425]
#  [1.38944344]] gradient_norm:  0.04593663631259933
# Epoch  5  weights:  [[0.02850748]
#  [1.43536977]] gradient_norm:  0.02290946922247609
# Epoch  6  weights:  [[0.02902929]
#  [1.45827329]] gradient_norm:  0.011425516148926226
# Epoch  7  weights:  [[0.02932597]
#  [1.46969496]] gradient_norm:  0.005698447990588387

# %%
#Changing epsilon (/1000)
alpha = 0.0001  # The learning Rate
epochs = 1000  # The number of iterations to perform gradient descent
weights = gradient_descent(alpha, epochs, 0.00000001, X, y)

y_hat = np.dot(PolynomialFeatures(1).fit_transform(X),weights)
plt.scatter(X, Y)
plt.plot([min(X), max(X)], [min(y_hat), max(y_hat)], color='red') # predicted
plt.show()
# Out:
# Epoch  0  weights:  [[0.]
#  [0.]] gradient_norm:  0.7425776579805078
# Epoch  1  weights:  [[0.0146299 ]
#  [0.74243353]] gradient_norm:  0.37033612440799285
# Epoch  2  weights:  [[0.02196252]
#  [1.11269705]] gradient_norm:  0.18469294028442376
# Epoch  3  weights:  [[0.02565587]
#  [1.29735306]] gradient_norm:  0.09210953494141266
# Epoch  4  weights:  [[0.02753425]
#  [1.38944344]] gradient_norm:  0.04593663631259933
# Epoch  5  weights:  [[0.02850748]
#  [1.43536977]] gradient_norm:  0.02290946922247609
# Epoch  6  weights:  [[0.02902929]
#  [1.45827329]] gradient_norm:  0.011425516148926226
# Epoch  7  weights:  [[0.02932597]
#  [1.46969496]] gradient_norm:  0.005698447990588387
# Epoch  8  weights:  [[0.02951038]
#  [1.47539042]] gradient_norm:  0.002842611872105721
# Epoch  9  weights:  [[0.02963879]
#  [1.47823013]] gradient_norm:  0.0014190593492850747
# Epoch  10  weights:  [[0.02973928]
#  [1.47964563]] gradient_norm:  0.0007105101264507278
# Epoch  11  weights:  [[0.02982583]
#  [1.48035084]] gradient_norm:  0.00035990524904816023
# Epoch  12  weights:  [[0.02990545]
#  [1.48070183]] gradient_norm:  0.00019023509467589473
# Epoch  13  weights:  [[0.02998159]
#  [1.48087616]] gradient_norm:  0.00011390055314186523
# Epoch  14  weights:  [[0.03005601]
#  [1.48096239]] gradient_norm:  8.484698683361231e-05
# Epoch  15  weights:  [[0.03012957]
#  [1.48100468]] gradient_norm:  7.591291273414453e-05
# Epoch  16  weights:  [[0.0302027 ]
#  [1.48102505]] gradient_norm:  7.35220506995282e-05
# Epoch  17  weights:  [[0.03027561]
#  [1.4810345 ]] gradient_norm:  7.291482476072303e-05
# Epoch  18  weights:  [[0.03034842]
#  [1.4810385 ]] gradient_norm:  7.276260766311581e-05
# Epoch  19  weights:  [[0.03042117]
#  [1.48103978]] gradient_norm:  7.272429699808341e-05
# Epoch  20  weights:  [[0.03049389]
#  [1.4810397 ]] gradient_norm:  7.271436328116101e-05

# %% [markdown]
# #### Analysis
# Taking into account alpha, we can observe that if we change it a bit, it achive its goal in more or less epochs depending if we increased or decreased this value. However, if we chage too much this value we can oberve how it wont converge and we wont have a result.
#
# We oberserved that if we have less epochs than it need to converge, we will have a solution but it wont be accurate.
#
# Finally if we change epsilon we can observe that if we increse it the result we obtain will needs less epochs and it will be less accurate. If we reduce epsilon it works the other way around, we need more epochs and we will have a better result.

# %% [markdown]
# ### Exercise 3: Comparison with closed form solution
# Use your code from lab 1 or the demo used in the course to implement the closed form solution for linear regression.

# %%
# Your code here
class my_linear_regression:
    def __init__(self) : # initialize constructor for the object to assign the object its properties
        self.X_train = []
        self.y_train = []
        self.weights = []
        
    def fit(self, X, y) :
        self.X_train = X
        self.y_train = y
        self.weights = np.linalg.solve(X.T@X,X.T@y)
    
    def predict(self,x_test) : # method of the object that can be used
        self.y_hat=np.sum(x_test*self.weights,axis=1)
        
        return self.y_hat
    
    def MSE(self,y_pred, y_test) :
        #YOUR CODE HERE
        MSE = 0
        for i in range(len(y_pred)):
            MSE += (y_pred[i]-y_test[i])**2
        MSE = MSE/len(y_pred)
        #YOUR CODE ENDS HERE
        return MSE
    
model_1=my_linear_regression()
model_1.fit(PolynomialFeatures(1).fit_transform(X),y)
print(f'The learned model has parameters:\n{model_1.weights}\n')
# Out:
# The learned model has parameters:
# [[9.90860619]
#  [1.28735737]]

# %% [markdown]
# ### Question 2: Comparison
# What are the differences between the results obtained with gradient descent and with the closed form solution.

# %%
alpha = 0.0001  # The learning Rate
epochs = 1000  # The number of iterations to perform gradient descent
weights1 = gradient_descent(alpha, epochs, 0.00001, X, y)
weights2 = model_1.weights

y_hat1 = np.dot(PolynomialFeatures(1).fit_transform(X),weights1)
y_hat2 = np.dot(PolynomialFeatures(1).fit_transform(X),weights2)

plt.scatter(X, Y)
plt.plot([min(X), max(X)], [min(y_hat1), max(y_hat1)], color='red') # predicted
plt.plot([min(X), max(X)], [min(y_hat2), max(y_hat2)], color='green') # predicted
plt.show()
acc1=0
acc2=0
for i in range(len(y)):
    acc1 = acc1 + (y[i]-y_hat1[i])**2
    acc2 = acc2 + (y[i]-y_hat2[i])**2
acc1= acc1/len(y)   
acc2= acc2/len(y) 
print('The gradient error: ' + str(acc1))
print('The closed error: ' + str(acc2))
# Out:
# Epoch  0  weights:  [[0.]
#  [0.]] gradient_norm:  0.7425776579805078
# Epoch  1  weights:  [[0.0146299 ]
#  [0.74243353]] gradient_norm:  0.37033612440799285
# Epoch  2  weights:  [[0.02196252]
#  [1.11269705]] gradient_norm:  0.18469294028442376
# Epoch  3  weights:  [[0.02565587]
#  [1.29735306]] gradient_norm:  0.09210953494141266
# Epoch  4  weights:  [[0.02753425]
#  [1.38944344]] gradient_norm:  0.04593663631259933
# Epoch  5  weights:  [[0.02850748]
#  [1.43536977]] gradient_norm:  0.02290946922247609
# Epoch  6  weights:  [[0.02902929]
#  [1.45827329]] gradient_norm:  0.011425516148926226
# Epoch  7  weights:  [[0.02932597]
#  [1.46969496]] gradient_norm:  0.005698447990588387
# Epoch  8  weights:  [[0.02951038]
#  [1.47539042]] gradient_norm:  0.002842611872105721
# Epoch  9  weights:  [[0.02963879]
#  [1.47823013]] gradient_norm:  0.0014190593492850747
# Epoch  10  weights:  [[0.02973928]
#  [1.47964563]] gradient_norm:  0.0007105101264507278
# Epoch  11  weights:  [[0.02982583]
#  [1.48035084]] gradient_norm:  0.00035990524904816023
# Epoch  12  weights:  [[0.02990545]
#  [1.48070183]] gradient_norm:  0.00019023509467589473
# Epoch  13  weights:  [[0.02998159]
#  [1.48087616]] gradient_norm:  0.00011390055314186523
# Epoch  14  weights:  [[0.03005601]
#  [1.48096239]] gradient_norm:  8.484698683361231e-05
# Epoch  15  weights:  [[0.03012957]
#  [1.48100468]] gradient_norm:  7.591291273414453e-05
# The gradient error: [111.0626459]
# The closed error: [107.47043701]

# %% [markdown]
# In this example both cases give similar results, we can see that from the graphic and from the calculation of the error. This is because we only have two dimensions. In the case we had more dimensions we should observe better results from the gradient than from the closed one.

# %% [markdown]
# ### Bonus
# Implement gradient descent using mini-batch and stochastic gradient descent.
